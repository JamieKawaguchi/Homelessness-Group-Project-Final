# %%
# Dependencies
import requests
import json
import pandas as pd
import hvplot.pandas
from pathlib import Path

# Import the API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ##  Begin Looking For State Lon and Lat

# %%
target_state = [
     'Montgomery, Alabama',
     'Juneau, Alaska',
    'Little Rock, Arkansas',
    'Phoenix, Arizona',
    'Sacramento, California',
    'Denver, Colorado',
    'Hartford, Connecticut',
    'Washington, District of Columbia',
    'Dover, Delaware',
    'Tallahassee, Florida',
    'Atlanta, Georgia',
    'Honolulu, Hawaii',
    'Des Moines, Iowa',
    'Boise, Idaho',
    'Springfield, Illinois',
    'Indianapolis, Indiana',
    'Topeka, Kansas',
    'Frankfort, Kentucky',
    'Baton Rouge, Louisiana',
    'Boston, Massachusetts',
    'Annapolis, Maryland',
    'Augusta, Maine',
    'Lansing, Michigan',
    'St. Paul, Minnesota',
    'Jefferson City, Missouri',
    'Jackson, Mississippi',
    'Helena, Montana',
    'Raleigh, North Carolina',
    'Bismarck, North Dakota',
    'Lincoln, Nebraska',
    'Concord, New Hampshire',
    'Trenton, New Jersey',
    'Santa Fe, New Mexico',
    'Carson City, Nevada',
    'Albany, New York',
    'Columbus, Ohio',
    'Oklahoma City, Oklahoma',
    'Salem, Oregon',
    'Harrisburg, Pennsylvania',
    'Providence, Rhode Island',
    'Columbia, South Carolina',
    'Pierre, South Dakota',
    'Nashville, Tennessee',
    'Austin, Texas',
    'Salt Lake City, Utah',
    'Richmond, Virginia',
    'Montpelier, Vermont',
    'Olympia, Washington',
    'Madison, Wisconsin',
    'Charleston, West Virginia',
    'Cheyenne, Wyoming'
]
state_array = len(target_state)
#print(state_array)
#print(target_state)

# %% [markdown]
# ## Loop each State through the api code

# %%
# COMPLETED LOOP FOR STATES and their coordinates 
state_cord = []

for x in range(state_array):
    target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_state[x]}&format=json&apiKey={geoapify_key}" 
    geo_data = requests.get(target_url).json()
    lat = geo_data["results"][0]["lat"]
    lon = geo_data["results"][0]["lon"]
    state_cord.append({"State": target_state[x],
                        "Lat": lat,
                        "Lon": lon})
    print(target_state[x], lat, lon) 
print("Done")      #state_cord.append(x)
# Out:
# Montgomery, Alabama 32.3669656 -86.3006485
# Juneau, Alaska 58.3019496 -134.419734
# Little Rock, Arkansas 34.7465071 -92.2896267
# Phoenix, Arizona 33.4484367 -112.074141
# Sacramento, California 38.5810606 -121.493895
# Denver, Colorado 39.7392364 -104.984862
# Hartford, Connecticut 41.764582 -72.6908547
# Washington, District of Columbia 38.8950368 -77.0365427
# Dover, Delaware 39.158168 -75.5243682
# Tallahassee, Florida 30.4380832 -84.2809332
# Atlanta, Georgia 33.7489924 -84.3902644
# Honolulu, Hawaii 21.304547 -157.855676
# Des Moines, Iowa 41.5910323 -93.6046655
# Boise, Idaho 43.6166163 -116.200886
# Springfield, Illinois 39.7990175 -89.6439575
# Indianapolis, Indiana 39.7683331 -86.1583502
# Topeka, Kansas 39.049011 -95.677556
# Frankfort, Kentucky 38.2009055 -84.8732836
# Baton Rouge, Louisiana 30.4494155 -91.1869659
# Boston, Massachusetts 42.3554334 -71.060511
# Annapolis, Maryland 38.9786401 -76.492786
# Augusta, Maine 44.3155295 -69.7700241
# ...

# %%
# Convert to dataframe
state_data_df = pd.DataFrame(state_cord)
state_data_df[['Capital', 'State']] = state_data_df['State'].str.split(', ', expand=True)
state_data_df.to_csv("states_cords.csv", index_label= "State_ID")
#state_data_df.head(5)

# %% [markdown]
# ## Test That Each State is plotted

# %%
# Plot States on the holoview plot
map_lat_lon = state_data_df.hvplot.points("Lon", "Lat", 
    geo = True, 
    scale = .1,          
    color = "State",         
    alpha =  1,               
    tiles = "OSM",  
    frame_width =700,
    frame_height = 300,
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("States"), 
)
map_lat_lon
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State)

# %% [markdown]
# # USA Zoomed In

# %%
map_city_NA = state_data_df.hvplot.points( "Lon", "Lat", 
    geo = True, 
    scale = .1,                # can help with making bubbles smaller and larger
    color = "State",           # Easy way to distinguish the states
    alpha =  1,               # opaccity of the bubbles
    tiles = "OSM", #"EsriImagery",  # makes it appear on tiles
    frame_width =700,
    frame_height = 300,                                       
 # Display North America states 
    xlim =(-115, -80),
    ylim=(30, 49),
# label the axis and title
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("USA"),
#hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
# Unhash once merged
)
map_city_NA
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State)

# %% [markdown]
# # HAWAII Zoomed In

# %%
# Plot Hawaii on the holoview plot
map_hawaii = state_data_df.hvplot.points("Lon", "Lat", 
    geo = True, 
    scale = 1,                # can help with making bubbles smaller and larger
    color = "State",          # Easy way to distinguish the states
    alpha = 1,                # opaccity of the bubbles
    tiles = "OSM", #"EsriImagery", # makes it appear on map
    frame_width =700,
    frame_height = 300,
# Displays hawaii
    xlim =(-160, -170),
    ylim=(15, 30),
# label the axis and title
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("Hawaii"),
#hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
# Unhash once merged
)
map_hawaii
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State)

# %% [markdown]
# # ALASKA Zoomed In

# %%
# Plot Alaska on the holoview plot
map_alaska = state_data_df.hvplot.points("Lon", "Lat", 
    geo = True, 
    scale = 1,                # can help with making bubbles smaller and larger
    color = "State",           # Easy way to distinguish the states
    alpha =  1,               # opaccity of the bubbles
    tiles = "OSM",  # makes it appear on map
    frame_width =700,
    frame_height = 300,                                     
# Displays alaska                                    
    xlim =(-130, -170),
    ylim=(50, 70), 
# label the axis and title                   
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("Alaska"),
#hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
# Unhash once merged
)
map_alaska
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------

# %% [markdown]
# # Maps After The Final DataFrame Merge

# %%
# Import data for homeless policy and homeless population in two csv files
policy_data_to_load = Path("2021-HNH-State-Crim-Supplement_Edited.csv")
population_data_to_load = Path("Homeless Population by State.csv")
states_ = Path("states_cords.csv")
# Read policy and population csv files and store in Pandas dataframes
homeless_laws = pd.read_csv(policy_data_to_load)
homeless_population = pd.read_csv(population_data_to_load)
states_cords = pd.read_csv(states_)

# %%
# Use pd.merge method to combine the dataframe into a single set using outer join 
homeless_merged = pd.merge(homeless_laws, homeless_population, how="outer", on=["State", "State"])

# Rename columns to be more intelligible to readers
homeless_states = homeless_merged.rename(columns={
                                                 'Sleeping in public state- wide':'Sleep in public statewide',
                                                 'Sleeping in particular public places':'Sleep in specific public places',
                                                 'Camping in public state- wide':'Camp in public statewide',
                                                 'Camping in particular public places': 'Camp in specific public places',
                                                 'Sitting/lying in particular public places':'Lying in specific public places',
                                                 'Lodging, living, or sleeping in vehicles (or parking a vehicle used as a lodging / living accom- modation)': 'Sleep/live in vehicle',
                                                 'Loitering / Loafing / Vagrancy state-wide' : 'Loitering statewide',
                                                 'Loitering / Loafing in particular public places': 'Loiter in specific public places',
                                                 'Standing in Roadway':'Standing in road',
                                                 'Panhandling in public places state- wide':'Panhandling statewide',
                                                 'Panhandling in particular public places':'Panhandling in specific public places',
                                                 'Total':'TotalPopulation'})
# Create ChronicPer10k column to measure chronic homeless population per 10,000 residents
homeless_states['ChronicPer10k'] = \
    homeless_states['Per10kResidents'] * homeless_states['ChronicallyHomeless'] / homeless_states['TotalPopulation']
# Print first five rows of dataframe with renamed columns
#homeless_states.head()

# %% [markdown]
# Handling any merged above here before the merge with the cordinates.

# %% [markdown]
# # Merge Data With the Cordinates

# %%
state_data = pd.merge(states_cords, homeless_states, how="inner", on=["State", "State"])
state_data.head()
# Out:
#    State_ID       State        Lat         Lon      Capital  \
# 0         0     Alabama  32.366966  -86.300648   Montgomery
# 1         1      Alaska  58.301950 -134.419734       Juneau
# 2         2    Arkansas  34.746507  -92.289627  Little Rock
# 3         3     Arizona  33.448437 -112.074141      Phoenix
# 4         4  California  38.581061 -121.493895   Sacramento
#
#    Sleep in public statewide  Sleep in specific public places  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                      False                            False
#
#    Camp in public statewide  Camp in specific public places  \
# 0                     False                           False
# 1                     False                            True
# ...

# %% [markdown]
# # CODE FOR PLOTTING MAPS

# %%
# Plot States_Data_df on the holoview plot
map_ = state_data.hvplot.points("Lon", "Lat", 
    geo = True, 
    scale = .1,          
    color = "State",         
    alpha =  1,               
    tiles = "OSM",  
    frame_width =700,
    frame_height = 300,
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("States"), 
    hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
)
map_
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,Capital,Restrictiveness Score,Per10kResidents,ChronicallyHomeless,PeopleInFamilyUnits,SoloIndividuals,UnaccompaniedYouths,Veterans)

# %% [markdown]
# # Zooming In, and Enhancing

# %%
pop_NA = state_data.hvplot.points( "Lon","Lat", 
    geo = True,                               
    size = "TotalPopulation",  # data point we want to plot                    
    scale = .1,                # can help with making bubbles smaller and larger
    color = "State",           # Easy way to distinguish the states
    alpha =  1,               # opaccity of the bubbles
    tiles =  "EsriStreet",#"OSM",            # makes it appear on map
    frame_width =700,
    frame_height = 300,
                                  
# Display North America states 
    xlim =(-115, -80),
    ylim=(30, 49),
# label the axis and title
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("Homelessness"),
    hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
)

# %%
pop_hawaii = state_data.hvplot.points("Lon", "Lat", 
    geo = True, 
    size = "TotalPopulation",  # data point we want to plot  
    scale = .1,                # can help with making bubbles smaller and larger
    color = "State",           # Easy way to distinguish the states
    alpha = 1,                 # opaccity of the bubbles
    tiles = "EsriNatGeo",#"OSM",             # makes it appear on map
    frame_width =700,
    frame_height = 300,
                                      
# Displays hawaii
    xlim =(-180, -155),
    ylim=(15, 30),
# label the axis and title
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("Homelessness in Hawaii"),
    hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
)

# %%
# Plot Alaska on the holoview plot
pop_alaska = state_data.hvplot.points("Lon", "Lat", 
    geo = True, 
    size = "TotalPopulation",  # data point we want to plot  
    scale = .1,                # can help with making bubbles smaller and larger
    color = "State",           # Easy way to distinguish the states
    alpha =  1,               # opaccity of the bubbles
    tiles = 'CartoLight', #'CartoLight',#"OSM",  # makes it appear on map
    frame_width =700,
    frame_height = 300, 
                                      
# Displays alaska                                    
    xlim =(-130, -170),
    ylim=(50, 70), 
# label the axis and title                   
    ylabel = ("Latitude"),
    xlabel = ("Longitude"),
    title = ("Homelessness in Alaska"),
    hover_cols = ['Capital','Restrictiveness Score','Per10kResidents','ChronicallyHomeless','PeopleInFamilyUnits','SoloIndividuals','UnaccompaniedYouths','Veterans']
)

# %% [markdown]
# # Maps Fully Displayed

# %%
pop_NA
# Homeless Data for each state
# Bubble size = total population
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,TotalPopulation,Capital,Restrictiveness Score,Per10kResidents,ChronicallyHomeless,PeopleInFamilyUnits,SoloIndividuals,UnaccompaniedYouths,Veterans)

# %%
pop_hawaii
# Homeless Data presented on Hawaii 
# Bubble size = total population
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,TotalPopulation,Capital,Restrictiveness Score,Per10kResidents,ChronicallyHomeless,PeopleInFamilyUnits,SoloIndividuals,UnaccompaniedYouths,Veterans)

# %%
pop_alaska
# Homeless in Alaska 
# Bubble size = total population
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (State,TotalPopulation,Capital,Restrictiveness Score,Per10kResidents,ChronicallyHomeless,PeopleInFamilyUnits,SoloIndividuals,UnaccompaniedYouths,Veterans)
